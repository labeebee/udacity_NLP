# %% [markdown]
# # Project: Part of Speech Tagging with Hidden Markov Models
# ---
# ### Introduction
#
# Part of speech tagging is the process of determining the syntactic category of a word from the words in its surrounding context. It is often used to help disambiguate natural language phrases because it can be done quickly with high accuracy. Tagging can be used for many NLP tasks like determining correct pronunciation during speech synthesis (for example, _dis_-count as a noun vs dis-_count_ as a verb), for information retrieval, and for word sense disambiguation.
#
# In this notebook, you'll use the [Pomegranate](http://pomegranate.readthedocs.io/) library to build a hidden Markov model for part of speech tagging using a "universal" tagset. Hidden Markov models have been able to achieve [>96% tag accuracy with larger tagsets on realistic text corpora](http://www.coli.uni-saarland.de/~thorsten/publications/Brants-ANLP00.pdf). Hidden Markov models have also been used for speech recognition and speech generation, machine translation, gene recognition for bioinformatics, and human gesture recognition for computer vision, and more.
#
# ![](_post-hmm.png)
#
# The notebook already contains some code to get you started. You only need to add some new functionality in the areas indicated to complete the project; you will not need to modify the included code beyond what is requested. Sections that begin with **'IMPLEMENTATION'** in the header indicate that you must provide code in the block that follows. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You must then **export the notebook** by running the last cell in the notebook, or by using the menu above and navigating to **File -> Download as -> HTML (.html)** Your submissions should include both the `html` and `ipynb` files.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** Code and Markdown cells can be executed using the `Shift + Enter` keyboard shortcut. Markdown cells can be edited by double-clicking the cell to enter edit mode.
# </div>

# %% [markdown]
# ### The Road Ahead
# You must complete Steps 1-3 below to pass the project. The section on Step 4 includes references & resources you can use to further explore HMM taggers.
#
# - [Step 1](#Step-1:-Read-and-preprocess-the-dataset): Review the provided interface to load and access the text corpus
# - [Step 2](#Step-2:-Build-a-Most-Frequent-Class-tagger): Build a Most Frequent Class tagger to use as a baseline
# - [Step 3](#Step-3:-Build-an-HMM-tagger): Build an HMM Part of Speech tagger and compare to the MFC baseline
# - [Step 4](#Step-4:-[Optional]-Improving-model-performance): (Optional) Improve the HMM tagger

# %% [markdown]
# <div class="alert alert-block alert-warning">
# **Note:** Make sure you have selected a **Python 3** kernel in Workspaces or the hmm-tagger conda environment if you are running the Jupyter server on your own machine.
# </div>

# %%
# Jupyter "magic methods" -- only need to be run once per kernel restart
# %load_ext autoreload
# %aimport helpers, tests
# %autoreload 1

# %%
# import python modules -- this cell needs to be run again if you make changes to any of the files
import matplotlib.pyplot as plt
import numpy as np

from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict
from helpers import show_model, Dataset
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution

# %% [markdown]
# ## Step 1: Read and preprocess the dataset
# ---
# We'll start by reading in a text corpus and splitting it into a training and testing dataset. The data set is a copy of the [Brown corpus](https://en.wikipedia.org/wiki/Brown_Corpus) (originally from the [NLTK](https://www.nltk.org/) library) that has already been pre-processed to only include the [universal tagset](https://arxiv.org/pdf/1104.2086.pdf). You should expect to get slightly higher accuracy using this simplified tagset than the same model would achieve on a larger tagset like the full [Penn treebank tagset](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html), but the process you'll follow would be the same.
#
# The `Dataset` class provided in helpers.py will read and parse the corpus. You can generate your own datasets compatible with the reader by writing them to the following format. The dataset is stored in plaintext as a collection of words and corresponding tags. Each sentence starts with a unique identifier on the first line, followed by one tab-separated word/tag pair on each following line. Sentences are separated by a single blank line.
#
# Example from the Brown corpus.
# ```
# b100-38532
# Perhaps	ADV
# it	PRON
# was	VERB
# right	ADJ
# ;	.
# ;	.
#
# b100-35577
# ...
# ```

# %%
data = Dataset("tags-universal.txt", "brown-universal.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 57340 sentences in the corpus.
# There are 45872 sentences in the training set.
# There are 11468 sentences in the testing set.

# %% [markdown]
# ### The Dataset Interface
#
# You can access (mostly) immutable references to the dataset through a simple interface provided through the `Dataset` class, which represents an iterable collection of sentences along with easy access to partitions of the data for training & testing. Review the reference below, then run and review the next few cells to make sure you understand the interface before moving on to the next step.
#
# ```
# Dataset-only Attributes:
#     training_set - reference to a Subset object containing the samples for training
#     testing_set - reference to a Subset object containing the samples for testing
#
# Dataset & Subset Attributes:
#     sentences - a dictionary with an entry {sentence_key: Sentence()} for each sentence in the corpus
#     keys - an immutable ordered (not sorted) collection of the sentence_keys for the corpus
#     vocab - an immutable collection of the unique words in the corpus
#     tagset - an immutable collection of the unique tags in the corpus
#     X - returns an array of words grouped by sentences ((w11, w12, w13, ...), (w21, w22, w23, ...), ...)
#     Y - returns an array of tags grouped by sentences ((t11, t12, t13, ...), (t21, t22, t23, ...), ...)
#     N - returns the number of distinct samples (individual words or tags) in the dataset
#
# Methods:
#     stream() - returns an flat iterable over all (word, tag) pairs across all sentences in the corpus
#     __iter__() - returns an iterable over the data as (sentence_key, Sentence()) pairs
#     __len__() - returns the nubmer of sentences in the dataset
# ```
#
# For example, consider a Subset, `subset`, of the sentences `{"s0": Sentence(("See", "Spot", "run"), ("VERB", "NOUN", "VERB")), "s1": Sentence(("Spot", "ran"), ("NOUN", "VERB"))}`. The subset will have these attributes:
#
# ```
# subset.keys == {"s1", "s0"}  # unordered
# subset.vocab == {"See", "run", "ran", "Spot"}  # unordered
# subset.tagset == {"VERB", "NOUN"}  # unordered
# subset.X == (("Spot", "ran"), ("See", "Spot", "run"))  # order matches .keys
# subset.Y == (("NOUN", "VERB"), ("VERB", "NOUN", "VERB"))  # order matches .keys
# subset.N == 7  # there are a total of seven observations over all sentences
# len(subset) == 2  # because there are two sentences
# ```
#
# <div class="alert alert-block alert-info">
# **Note:** The `Dataset` class is _convenient_, but it is **not** efficient. It is not suitable for huge datasets because it stores multiple redundant copies of the same data.
# </div>

# %% [markdown]
# #### Sentences
#
# `Dataset.sentences` is a dictionary of all sentences in the training corpus, each keyed to a unique sentence identifier. Each `Sentence` is itself an object with two attributes: a tuple of the words in the sentence named `words` and a tuple of the tag corresponding to each word named `tags`.

# %%
key = 'b100-38532'
print("Sentence: {}".format(data.sentences[key]))
print("words:\n\t{!s}".format(data.sentences[key].words))
print("tags:\n\t{!s}".format(data.sentences[key].tags))
# Out:
# Sentence: Sentence(words=('Perhaps', 'it', 'was', 'right', ';', ';'), tags=('ADV', 'PRON', 'VERB', 'ADJ', '.', '.'))
# words:
# 	('Perhaps', 'it', 'was', 'right', ';', ';')
# tags:
# 	('ADV', 'PRON', 'VERB', 'ADJ', '.', '.')

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** The underlying iterable sequence is **unordered** over the sentences in the corpus; it is not guaranteed to return the sentences in a consistent order between calls. Use `Dataset.stream()`, `Dataset.keys`, `Dataset.X`, or `Dataset.Y` attributes if you need ordered access to the data.
# </div>
#
# #### Counting Unique Elements
#
# You can access the list of unique words (the dataset vocabulary) via `Dataset.vocab` and the unique list of tags via `Dataset.tagset`.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 1161192 samples of 56057 unique words in the corpus.
# There are 928458 samples of 50536 unique words in the training set.
# There are 232734 samples of 25112 unique words in the testing set.
# There are 5521 words in the test set that are missing in the training set.

# %% [markdown]
# #### Accessing word and tag Sequences
# The `Dataset.X` and `Dataset.Y` attributes provide access to ordered collections of matching word and tag sequences for each sentence in the dataset.

# %%
print(data.tagset)
# Out:
# frozenset({'NOUN', 'X', 'PRON', 'NUM', 'VERB', 'PRT', 'ADP', 'ADV', 'CONJ', 'DET', 'ADJ', '.'})

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('Mr.', 'Podger', 'had', 'thanked', 'him', 'gravely', ',', 'and', 'now', 'he', 'made', 'use', 'of', 'the', 'advice', '.')
#
# Labels 1: ('NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
# Sentence 2: ('But', 'there', 'seemed', 'to', 'be', 'some', 'difference', 'of', 'opinion', 'as', 'to', 'how', 'far', 'the', 'board', 'should', 'go', ',', 'and', 'whose', 'advice', 'it', 'should', 'follow', '.')
#
# Labels 2: ('CONJ', 'PRT', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', '.')

# %% [markdown]
# #### Accessing (word, tag) Samples
# The `Dataset.stream()` method returns an iterator that chains together every pair of (word, tag) entries across all sentences in the entire corpus.

# %%
# use Dataset.stream() (word, tag) samples for the entire corpus
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 5: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('Mr.', 'NOUN')
# 	 ('Podger', 'NOUN')
# 	 ('had', 'VERB')
# 	 ('thanked', 'VERB')
# 	 ('him', 'PRON')
# 	 ('gravely', 'ADV')
# 	 (',', '.')

# %% [markdown]
# For both our baseline tagger and the HMM model we'll build, we need to estimate the frequency of tags & words from the frequency counts of observations in the training corpus. In the next several cells you will complete functions to compute the counts of several sets of counts.

# %% [markdown]
# ## Step 2: Build a Most Frequent Class tagger
# ---
#
# Perhaps the simplest tagger (and a good baseline for tagger performance) is to simply choose the tag most frequently assigned to each word. This "most frequent class" tagger inspects each observed word in the sequence and assigns it the label that was most often assigned to that word in the corpus.

# %% [markdown]
# ### IMPLEMENTATION: Pair Counts
#
# Complete the function below that computes the joint frequency counts for two input sequences.

# %%
def pair_counts(sequences_A, sequences_B):
    """Return a dictionary keyed to each unique value in the first sequence list
    that counts the number of occurrences of the corresponding value from the
    second sequences list.
    
    For example, if sequences_A is tags and sequences_B is the corresponding
    words, then if 1244 sequences contain the word "time" tagged as a NOUN, then
    you should return a dictionary such that pair_counts[NOUN][time] == 1244
    """
    # TODO: Finish this function!
    counts = {}
    for i in range (len(sequences_A)):
        for tag, word in zip(sequences_A[i], sequences_B[i]):
            if tag not in counts:
                counts[tag] = {}
            counts[tag][word] = counts[tag].get(word, 0)+1
    return counts
    raise NotImplementedError


# Calculate C(t_i, w_i)
emission_counts = pair_counts(data.Y, data.X)

assert len(emission_counts) == 12, \
       "Uh oh. There should be 12 tags in your dictionary."
assert max(emission_counts["NOUN"], key=emission_counts["NOUN"].get) == 'time', \
       "Hmmm...'time' is expected to be the most common NOUN."
HTML('<div class="alert alert-block alert-success">Your emission counts look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your emission counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Most Frequent Class Tagger
#
# Use the `pair_counts()` function and the training dataset to find the most frequent class label for each word in the training data, and populate the `mfc_table` below. The table keys should be words, and the values should be the appropriate tag string.
#
# The `MFCTagger` class is provided to mock the interface of Pomegranite HMM models so that they can be used interchangeably.

# %%
data.training_set.Y
# Out:
# (('ADV',
#   'NOUN',
#   '.',
#   'ADV',
#   '.',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'NUM',
#   '.',
#   'NUM',
#   '.',
#   '.',
#   '.'),
#  ('ADP',
#   'ADV',
#   'NUM',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   'VERB',
#   '.',
#   'VERB',
#   '.',
#   'VERB',
#   '.'),
#  ('ADJ', 'NOUN'),
#  ('ADV',
#   '.',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.',
#   'NUM',
#   '.'),
#  ('PRT',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('NOUN', 'VERB', '.', 'VERB', 'DET', 'NOUN', '.'),
#  ('NOUN', 'VERB', '.'),
#  ('NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.'),
#  ('NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.'),
#  ('NOUN', '.', 'ADJ', '.'),
#  ('NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'PRT',
#   'VERB',
#   'PRON',
#   '.',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'DET',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('ADV',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('CONJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   '.'),
#  ('PRT',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'VERB',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN', '.', 'NOUN', 'NUM'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADP',
#   'PRT',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   '.',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   '.'),
#  ('CONJ',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NUM',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'PRON',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADV',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.'),
#  ('ADJ',
#   'ADP',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADV',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'NUM',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN'),
#  ('NOUN', 'VERB', '.'),
#  ('ADP',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRT',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'ADP', 'NOUN', 'CONJ', 'VERB', 'PRT', 'DET', 'NOUN', '.'),
#  ('CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'VERB',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('DET',
#   '.',
#   'ADV',
#   '.',
#   'VERB',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADP',
#   'DET',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'ADV',
#   '.',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   'PRT',
#   '.',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NUM',
#   'NUM',
#   '.'),
#  ('.', 'PRON', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', 'ADV', '.', '.'),
#  ('CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('.', 'PRT', 'VERB', 'DET', 'NOUN', '.'),
#  ('PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('NOUN', '.'),
#  ('.', 'NOUN', '.', 'DET', 'NOUN', 'PRT', 'VERB', 'NOUN', 'NOUN', '.'),
#  ('DET', 'ADJ', '.', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADV', '.', 'ADV', '.'),
#  ('ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'VERB',
#   'VERB',
#   'ADJ',
#   '.'),
#  ('DET',
#   'ADP',
#   'DET',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   '.',
#   'CONJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   'NUM',
#   '.',
#   '.'),
#  ('DET',
#   'ADV',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'VERB',
#   'DET',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADV',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADV',
#   '.'),
#  ('DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   '.'),
#  ('PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('NOUN', 'VERB', 'NOUN'),
#  ('ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.',
#   'PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'CONJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('CONJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   '.'),
#  ('NUM',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.'),
#  ('.',
#   'PRON',
#   'VERB',
#   '.',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'),
#  ('NOUN',
#   'ADP',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADJ',
#   '.',
#   '.'),
#  ('DET', 'NOUN', 'DET', 'VERB', 'CONJ', 'VERB', 'NOUN', 'CONJ', 'NOUN', '.'),
#  ('NUM',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'PRT',
#   'VERB',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET', 'PRT', 'NOUN', 'NOUN', '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.',
#   'NOUN',
#   '.',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRT', 'PRT', 'DET', 'ADJ', 'NOUN', '.', '.', 'PRON', 'VERB', '.'),
#  ('PRT',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   '.',
#   'CONJ',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'ADJ',
#   '.'),
#  ('PRT',
#   'VERB',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADP',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'PRON',
#   'PRT',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('.', 'ADV', '.'),
#  ('NUM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.'),
#  ('ADV',
#   'PRON',
#   '.',
#   'VERB',
#   'PRON',
#   '.',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'ADV',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.'),
#  ('NOUN', 'NOUN'),
#  ('DET',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('.', 'PRON', 'VERB', 'PRT', 'VERB', 'ADJ', '.', 'PRT', '.', '.'),
#  ('PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'PRON',
#   'VERB',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('ADV',
#   '.',
#   'PRT',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('ADV',
#   'PRON',
#   'VERB',
#   '.',
#   'ADV',
#   '.',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PRON',
#   '.',
#   'ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADV',
#   '.',
#   'ADV',
#   '.',
#   '.',
#   '.'),
#  ('ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'VERB',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADV',
#   'NOUN',
#   '.'),
#  ('.',
#   'PRT',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'PRT',
#   'CONJ',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'PRON', 'ADP', 'ADJ', 'NOUN', '.'),
#  ('ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADJ',
#   '.',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   '.'),
#  ('DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRON',
#   '.',
#   '.',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.',
#   '.'),
#  ('VERB', 'CONJ', 'VERB'),
#  ('DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'ADP',
#   'DET',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   '.',
#   'ADP',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.'),
#  ('PRON', 'VERB', 'DET', 'NUM', '.'),
#  ('PRON',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('NUM',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'CONJ',
#   'NUM',
#   '.',
#   '.',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRT', 'VERB', 'DET', 'ADJ', 'NOUN', '.'),
#  ('PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'ADJ',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('ADV',
#   'DET',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'),
#  ('DET',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADJ',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'DET',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('.', 'VERB', 'PRON', 'DET', 'NOUN', '.', '.', '.'),
#  ('DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADV',
#   'PRT',
#   'VERB',
#   'PRT',
#   '.',
#   'CONJ',
#   'NOUN',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'ADV',
#   '.',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.'),
#  ('PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN', 'CONJ', 'ADJ', 'NOUN', '.', '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'),
#  ('ADP',
#   'DET',
#   'VERB',
#   'VERB',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PRT',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'CONJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'ADP',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   '.',
#   '.'),
#  ('CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('ADV',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   '.',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'DET',
#   'DET',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   '.'),
#  ('DET',
#   'VERB',
#   '.',
#   'PRT',
#   'VERB',
#   'PRON',
#   'ADV',
#   '.',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'VERB',
#   '.'),
#  ('.', 'PRT', '.', 'PRT', '.', '.', 'DET', 'NOUN', 'VERB', '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   '.',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   '.'),
#  ('NOUN', 'VERB', 'VERB', '.', 'NOUN', 'VERB', 'ADV', 'VERB', '.'),
#  ('ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRT',
#   'VERB',
#   'DET',
#   'PRON',
#   'VERB',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NUM',
#   '.',
#   'ADV',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'NUM',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.'),
#  ('ADP',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'VERB',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'ADV',
#   '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'VERB', 'DET', 'NOUN', 'ADV', '.'),
#  ('PRT',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'VERB',
#   'DET',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'NOUN', '.'),
#  ('DET',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'),
#  ('X',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'PRON', 'ADV', '.'),
#  ('NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.',
#   '.'),
#  ('NOUN', 'CONJ', 'NOUN', 'NOUN', 'VERB', 'ADJ', 'NOUN', '.'),
#  ('ADJ',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'NUM',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRON',
#   '.',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NUM',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('CONJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', '.'),
#  ('DET',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'ADP',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NUM',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADJ', 'NOUN'),
#  ('NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('ADV',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('NOUN', 'VERB', 'NOUN', 'ADP', 'NOUN'),
#  ('ADP',
#   'DET',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('VERB',
#   '.',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   '.',
#   '.'),
#  ('PRON', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'NOUN', '.'),
#  ('.',),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   '.',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.',
#   'VERB',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRT',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('VERB',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'ADJ',
#   '.',
#   'ADJ',
#   '.',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'),
#  ('VERB',
#   'DET',
#   '.',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.'),
#  ('NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRT',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'PRT',
#   'DET',
#   'NOUN',
#   'X',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN', 'ADV', 'ADJ'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   'VERB',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.',
#   '.',
#   'DET',
#   'ADJ',
#   'ADP',
#   'DET',
#   '.',
#   'ADJ',
#   '.',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('CONJ',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.'),
#  ('PRON', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'ADJ', 'ADP', '.'),
#  ('CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADV',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'VERB',
#   'NOUN',
#   '.',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADV',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   '.',
#   'VERB',
#   'PRON',
#   'CONJ',
#   'VERB',
#   '.',
#   '.'),
#  ('NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'VERB',
#   'PRT',
#   '.'),
#  ('PRON',
#   'VERB',
#   'PRON',
#   '.',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NUM',
#   'PRON',
#   'VERB',
#   'ADP',
#   'CONJ',
#   'DET',
#   'NUM',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'PRT',
#   '.'),
#  ('ADP',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'ADV',
#   '.',
#   'CONJ',
#   'DET',
#   'PRON',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'ADV', 'VERB', '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN', 'NOUN'),
#  ('NOUN',
#   'VERB',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'ADP',
#   'VERB',
#   'PRT',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'),
#  ('ADP',
#   'NUM',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'),
#  ('.',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   '.'),
#  ('DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'CONJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADV',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'ADV',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('ADV', 'ADP', 'DET', '.', 'ADV', '.', '.', '.'),
#  ('PRON', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADV', 'ADJ', 'NOUN', '.'),
#  ('PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   '.',
#   'ADV',
#   '.',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   '.'),
#  ('NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', '.'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   '.',
#   'ADJ',
#   'ADP',
#   'PRON',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NUM',
#   '.',
#   '.'),
#  ('ADP',
#   'PRT',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NUM',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('.', 'PRON', 'VERB', 'VERB', '.', 'NOUN', '.'),
#  ('NUM', 'NOUN'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.'),
#  ('ADP',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   '.',
#   'DET',
#   '.'),
#  ('PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   '.'),
#  ('ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NUM',
#   'ADP',
#   'NUM',
#   'ADV',
#   'ADP',
#   'NUM',
#   'ADP',
#   'NUM',
#   'ADV',
#   '.'),
#  ('.',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   'DET',
#   'NOUN',
#   'DET',
#   '.',
#   'VERB',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADV',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   '.'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADP',
#   'DET',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'PRON',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   '.',
#   '.'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('CONJ',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   '.'),
#  ('DET', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('NOUN', 'NOUN', 'VERB', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', '.'),
#  ('PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADV',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'PRON',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('CONJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   '.'),
#  ('.', 'ADV', 'ADP', 'NOUN', 'ADV', '.', '.', 'NOUN', 'VERB', 'ADV', '.'),
#  ('.', 'ADV', 'VERB', 'PRON', 'VERB', '.', '.'),
#  ('PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADJ',
#   '.',
#   'ADP',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'DET',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'),
#  ('DET',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('NUM', '.'),
#  ('PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('DET', 'NOUN', '.', 'PRT', 'VERB', '.', 'ADP', 'DET', 'NOUN', '.'),
#  ('PRON', 'VERB', '.', '.', 'DET', 'VERB', 'VERB', 'ADJ', 'NOUN', 'ADV', '.'),
#  ('ADJ',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.'),
#  ('DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   '.',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'),
#  ('ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'VERB',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'CONJ',
#   'PRT',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'VERB',
#   'DET',
#   'NOUN',
# ...
#  ('NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'),
#  ('NOUN', 'VERB', 'VERB', 'ADJ'),
#  ('ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'ADV', '.'),
#  ('VERB',
#   'PRON',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADP',
#   'ADV',
#   '.',
#   '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'CONJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'),
#  ('PRT', 'VERB', 'ADV', 'ADJ', 'NOUN', 'PRON', 'VERB', 'ADJ', 'NOUN', '.'),
#  ('PRON',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'CONJ',
#   'VERB',
#   '.',
#   'VERB',
#   'CONJ',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('ADV',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'),
#  ('PRON', 'ADV', 'VERB', 'DET', 'ADJ', 'NOUN', '.'),
#  ('VERB', 'NOUN', 'ADJ'),
#  ('ADV', 'NOUN', 'PRON', 'VERB', '.', 'ADP', 'ADJ', 'NOUN', '.'),
#  ('NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   '.'),
#  ('ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRT',
#   'VERB',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   'ADV',
#   '.',
#   'ADP',
#   'VERB',
#   'NUM',
#   '.',
#   'NUM',
#   '.',
#   'CONJ',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('VERB',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NUM',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.'),
#  ('PRT',
#   'VERB',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   '.',
#   'ADV',
#   'ADJ',
#   '.',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADP',
#   'CONJ',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET', 'ADJ', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADP', 'PRON', '.', '.'),
#  ('VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   'PRT',
#   'VERB',
#   '.',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('NOUN', 'ADP', 'PRON', '.', 'DET', 'NOUN', 'ADP', 'NOUN', '.'),
#  ('VERB', 'ADP', 'ADV', 'VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'),
#  ('DET',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   '.',
#   '.'),
#  ('ADV',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   '.'),
#  ('ADP',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('ADV',
#   '.',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'),
#  ('NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'VERB',
#   'PRT',
#   'NUM',
#   'NUM',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRT',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.'),
#  ('PRON', 'VERB', 'VERB', 'DET', 'NOUN', '.'),
#  ('.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADV',
#   'CONJ',
#   'PRT',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADV',
#   'ADP',
#   'PRON',
#   '.',
#   '.',
#   '.'),
#  ('DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'ADP',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'ADV',
#   '.',
#   '.',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'),
#  ('ADV',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADV',
#   '.',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON', 'CONJ', 'NOUN', 'VERB', 'VERB', 'ADV', 'ADP', 'NUM', 'NOUN', '.'),
#  ('PRT',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'ADP',
#   'VERB',
#   'PRON',
#   '.',
#   'VERB',
#   'PRT',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'VERB',
#   'PRT',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'),
#  ('CONJ', 'PRON', 'VERB', 'VERB', 'PRT', 'ADP', 'PRON', '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('VERB',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('ADJ', 'VERB', 'ADP', 'VERB'),
#  ('PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'NOUN', 'ADV', '.'),
#  ('ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('.',
#   'VERB',
#   'PRON',
#   'PRT',
#   '.',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NUM',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'PRON',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN', 'VERB', 'VERB', 'DET', 'NUM', 'ADJ', 'NOUN', 'DET', 'NOUN', '.'),
#  ('ADV',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   '.',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRT',
#   'ADP',
#   'PRON',
#   '.'),
#  ('PRT',
#   'ADP',
#   'DET',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'),
#  ('PRT',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'),
#  ('PRON',
#   'VERB',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'),
#  ('PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.'),
#  ('ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'),
#  ('DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   '.'),
#  ('ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'),
#  ('NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   '.',
#   'VERB',
#   '.',
#   '.'),
#  ('PRON',
#   'VERB',
#   '.',
#   'ADV',
#   '.',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.'),
#  ('PRON', 'VERB', 'PRON', 'VERB', '.', '.', '.'),
#  ('NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADJ',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   '.'),
#  ('DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   '.',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'),
#  ('ADJ', 'NOUN', 'VERB', 'ADP', 'NUM', 'ADJ', 'NOUN', '.'),
#  ('ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'),
#  ...)

# %%
# Create a lookup table mfc_table where mfc_table[word] contains the tag label most frequently assigned to that word
from collections import namedtuple

FakeState = namedtuple("FakeState", "name")

class MFCTagger:
    # NOTE: You should not need to modify this class or any of its methods
    missing = FakeState(name="<MISSING>")
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))


# TODO: calculate the frequency of each tag being assigned to each word (hint: similar, but not
# the same as the emission probabilities) and use it to fill the mfc_table

word_counts = pair_counts(data.training_set.X, data.training_set.Y)
def most_freq(count_dict):
    return sorted(count_dict, key=count_dict.get, reverse=True)[0]
mfc_table = {word:most_freq(word_counts[word]) for word in word_counts.keys()}


# DO NOT MODIFY BELOW THIS LINE
mfc_model = MFCTagger(mfc_table) # Create a Most Frequent Class tagger instance

assert len(mfc_table) == len(data.training_set.vocab), ""
assert all(k in data.training_set.vocab for k in mfc_table.keys()), ""
assert sum(int(k not in mfc_table) for k in data.testing_set.vocab) == 5521, ""
HTML('<div class="alert alert-block alert-success">Your MFC tagger has all the correct words!</div>')
# Out:
# <div class="alert alert-block alert-success">Your MFC tagger has all the correct words!</div>

# %% [markdown]
# ### Making Predictions with a Model
# The helper functions provided below interface with Pomegranate network models & the mocked MFCTagger to take advantage of the [missing value](http://pomegranate.readthedocs.io/en/latest/nan.html) functionality in Pomegranate through a simple sequence decoding function. Run these functions, then run the next cell to see some of the predictions made by the MFC tagger.

# %%
def replace_unknown(sequence):
    """Return a copy of the input sequence where each unknown word is replaced
    by the literal string value 'nan'. Pomegranate will ignore these values
    during computation.
    """
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):
    """X should be a 1-D sequence of observations for the model to predict"""
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]  # do not show the start/end state predictions

# %% [markdown]
# ### Example Decoding Sequences with MFC Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-28144
#
# Predicted labels:
# -----------------
# ['CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.']
#
# Actual labels:
# --------------
# ('CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.')
#
#
# Sentence Key: b100-23146
#
# Predicted labels:
# -----------------
# ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
#
# Actual labels:
# --------------
# ('PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
#
# Sentence Key: b100-35462
#
# Predicted labels:
# -----------------
# ['DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', '<MISSING>', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADV', 'NOUN', '.']
#
# Actual labels:
# --------------
# ('DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')

# %% [markdown]
# ### Evaluating Model Accuracy
#
# The function below will evaluate the accuracy of the MFC tagger on the collection of all sentences from a text corpus.

# %%
def accuracy(X, Y, model):
    """Calculate the prediction accuracy by using the model to decode each sequence
    in the input X and comparing the prediction with the true labels in Y.
    
    The X should be an array whose first dimension is the number of sentences to test,
    and each element of the array should be an iterable of the words in the sequence.
    The arrays X and Y should have the exact same shape.
    
    X = [("See", "Spot", "run"), ("Run", "Spot", "run", "fast"), ...]
    Y = [(), (), ...]
    """
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %% [markdown]
# #### Evaluate the accuracy of the MFC tagger
# Run the next cell to evaluate the accuracy of the tagger on the training and test corpus.

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))

assert mfc_training_acc >= 0.955, "Uh oh. Your MFC accuracy on the training set doesn't look right."
assert mfc_testing_acc >= 0.925, "Uh oh. Your MFC accuracy on the testing set doesn't look right."
HTML('<div class="alert alert-block alert-success">Your MFC tagger accuracy looks correct!</div>')
# Out:
# training accuracy mfc_model: 95.72%
# testing accuracy mfc_model: 93.01%
# <div class="alert alert-block alert-success">Your MFC tagger accuracy looks correct!</div>

# %% [markdown]
# ## Step 3: Build an HMM tagger
# ---
# The HMM tagger has one hidden state for each possible tag, and parameterized by two distributions: the emission probabilties giving the conditional probability of observing a given **word** from each hidden state, and the transition probabilities giving the conditional probability of moving between **tags** during the sequence.
#
# We will also estimate the starting probability distribution (the probability of each **tag** being the first tag in a sequence), and the terminal probability distribution (the probability of each **tag** being the last tag in a sequence).
#
# The maximum likelihood estimate of these distributions can be calculated from the frequency counts as described in the following sections where you'll implement functions to count the frequencies, and finally build the model. The HMM model will make predictions according to the formula:
#
# $$t_i^n = \underset{t_i^n}{\mathrm{argmax}} \prod_{i=1}^n P(w_i|t_i) P(t_i|t_{i-1})$$
#
# Refer to Speech & Language Processing [Chapter 10](https://web.stanford.edu/~jurafsky/slp3/10.pdf) for more information.

# %% [markdown]
# ### IMPLEMENTATION: Unigram Counts
#
# Complete the function below to estimate the co-occurrence frequency of each symbol over all of the input sequences. The unigram probabilities in our HMM model are estimated from the formula below, where N is the total number of samples in the input. (You only need to compute the counts for now.)
#
# $$P(tag_1) = \frac{C(tag_1)}{N}$$

# %%
def unigram_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequence list that
    counts the number of occurrences of the value in the sequences list. The sequences
    collection should be a 2-dimensional array.
    
    For example, if the tag NOUN appears 275558 times over all the input sequences,
    then you should return a dictionary such that your_unigram_counts[NOUN] == 275558.
    """
    # TODO: Finish this function!
    counts = {}
    for tag in data.training_set.tagset:
        for sequence in sequences:
            for tag in sequence:
                counts[tag] = counts.get(tag, 0)+1
    return counts
    raise NotImplementedError

# TODO: call unigram_counts with a list of tag sequences from the training set
tag_unigrams = unigram_counts(data.training_set.Y)

assert set(tag_unigrams.keys()) == data.training_set.tagset, \
       "Uh oh. It looks like your tag counts doesn't include all the tags!"
assert min(tag_unigrams, key=tag_unigrams.get) == 'X', \
       "Hmmm...'X' is expected to be the least common class"
assert max(tag_unigrams, key=tag_unigrams.get) == 'NOUN', \
       "Hmmm...'NOUN' is expected to be the most common class"
HTML('<div class="alert alert-block alert-success">Your tag unigrams look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your tag unigrams look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Bigram Counts
#
# Complete the function below to estimate the co-occurrence frequency of each pair of symbols in each of the input sequences. These counts are used in the HMM model to estimate the bigram probability of two tags from the frequency counts according to the formula: $$P(tag_2|tag_1) = \frac{C(tag_2|tag_1)}{C(tag_2)}$$

# %%
def bigram_counts(sequences):
    """Return a dictionary keyed to each unique PAIR of values in the input sequences
    list that counts the number of occurrences of pair in the sequences list. The input
    should be a 2-dimensional array.
    
    For example, if the pair of tags (NOUN, VERB) appear 61582 times, then you should
    return a dictionary such that your_bigram_counts[(NOUN, VERB)] == 61582
    """
    counts = defaultdict(int)
    for sequence in sequences:
        for tag1, tag2 in zip(sequence[:-1], sequence[1:]):
            counts[(tag1, tag2)]+=1
    return counts
    # TODO: Finish this function!
    raise NotImplementedError

# TODO: call bigram_counts with a list of tag sequences from the training set
tag_bigrams = bigram_counts(data.training_set.Y)

assert len(tag_bigrams) == 144, \
       "Uh oh. There should be 144 pairs of bigrams (12 tags x 12 tags)"
assert min(tag_bigrams, key=tag_bigrams.get) in [('X', 'NUM'), ('PRON', 'X')], \
       "Hmmm...The least common bigram should be one of ('X', 'NUM') or ('PRON', 'X')."
assert max(tag_bigrams, key=tag_bigrams.get) in [('DET', 'NOUN')], \
       "Hmmm...('DET', 'NOUN') is expected to be the most common bigram."
HTML('<div class="alert alert-block alert-success">Your tag bigrams look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your tag bigrams look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Sequence Starting Counts
# Complete the code below to estimate the bigram probabilities of a sequence starting with each tag.

# %%
def starting_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequences list
    that counts the number of occurrences where that value is at the beginning of
    a sequence.
    
    For example, if 8093 sequences start with NOUN, then you should return a
    dictionary such that your_starting_counts[NOUN] == 8093
    """
    counts = {}
    for sequence in sequences:
        counts[sequence[0]] = counts.get(sequence[0], 0)+1
    return counts
    # TODO: Finish this function!
    raise NotImplementedError

# TODO: Calculate the count of each tag starting a sequence
tag_starts = starting_counts(data.training_set.Y)

assert len(tag_starts) == 12, "Uh oh. There should be 12 tags in your dictionary."
assert min(tag_starts, key=tag_starts.get) == 'X', "Hmmm...'X' is expected to be the least common starting bigram."
assert max(tag_starts, key=tag_starts.get) == 'DET', "Hmmm...'DET' is expected to be the most common starting bigram."
HTML('<div class="alert alert-block alert-success">Your starting tag counts look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your starting tag counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Sequence Ending Counts
# Complete the function below to estimate the bigram probabilities of a sequence ending with each tag.

# %%
def ending_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequences list
    that counts the number of occurrences where that value is at the end of
    a sequence.
    
    For example, if 18 sequences end with DET, then you should return a
    dictionary such that your_starting_counts[DET] == 18
    """
    # TODO: Finish this function!
    counts = {}
    for sequence in sequences:
        counts[sequence[-1]] = counts.get(sequence[-1], 0)+1
    return counts
    raise NotImplementedError

# TODO: Calculate the count of each tag ending a sequence
tag_ends = ending_counts(data.training_set.Y)

assert len(tag_ends) == 12, "Uh oh. There should be 12 tags in your dictionary."
assert min(tag_ends, key=tag_ends.get) in ['X', 'CONJ'], "Hmmm...'X' or 'CONJ' should be the least common ending bigram."
assert max(tag_ends, key=tag_ends.get) == '.', "Hmmm...'.' is expected to be the most common ending bigram."
HTML('<div class="alert alert-block alert-success">Your ending tag counts look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your ending tag counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Basic HMM Tagger
# Use the tag unigrams and bigrams calculated above to construct a hidden Markov tagger.
#
# - Add one state per tag
#     - The emission distribution at each state should be estimated with the formula: $P(w|t) = \frac{C(t, w)}{C(t)}$
# - Add an edge from the starting state `basic_model.start` to each tag
#     - The transition probability should be estimated with the formula: $P(t|start) = \frac{C(start, t)}{C(start)}$
# - Add an edge from each tag to the end state `basic_model.end`
#     - The transition probability should be estimated with the formula: $P(end|t) = \frac{C(t, end)}{C(t)}$
# - Add an edge between _every_ pair of tags
#     - The transition probability should be estimated with the formula: $P(t_2|t_1) = \frac{C(t_1, t_2)}{C(t_1)}$

# %%
tag_unigrams
# Out:
# {'ADV': 538524,
#  'NOUN': 2647584,
#  '.': 1413084,
#  'VERB': 1753932,
#  'ADP': 1389696,
#  'ADJ': 801048,
#  'CONJ': 366444,
#  'DET': 1316052,
#  'PRT': 286872,
#  'NUM': 142536,
#  'PRON': 472596,
#  'X': 13128}

# %%
emission_counts['NOUN'].keys()
# Out:
# dict_keys(['Mr.', 'Podger', 'use', 'advice', 'difference', 'opinion', 'board', 'instrument', 'elasticity', 'pastes', 'inks', 'paints', 'adhesives', 'plastics', 'bread', 'dough', 'properties', 'length', 'shortness', 'spinnability', 'methods', 'present', 'plans', 'language', 'teacher', 'east', 'mile', 'road', 'effort', 'sweat', 'television', 'Line', 'tour', 'Beach', 'night', 'opportunity', 'measure', 'adversary', 'war', "Khrushchev's", 'intentions', 'views', 'direction', 'place', 'philosopher', 'Samuel', "Alexander's", 'debt', 'Wordsworth', 'Meredith', 'example', 'A.', 'N.', "Whitehead's", 'understanding', 'romantics', 'Shelley', 'network', 'entities', 'manner', 'regard', 'needs', 'society', 'regime', "corporation's", 'survival', 'responsibility', 'conditions', 'assistance', 'scale', 'definition', 'objectives', 'assessment', 'costs', 'Theresa', 'Anne', 'George', 'degree', 'Af', 'P', 'teen', 'life', 'non-college', 'group', 'sense', 'marginality', 'tempest', 'March', 'Udall', 'bronze', 'statue', 'William', 'Jennings', 'Bryan', 'Gutzon', 'Borglum', 'loan', 'Salem', 'Illinois', "Bryan's", 'birthplace', 'case', 'elements', 'pencil', 'secant', 'line', 'vertex', 'intersection', '**zg', 'plane', 'howl', 'coming', 'times', 'veterinarian', 'Kennan', 'account', 'circumstance', 'atmosphere', 'decisions', 'approach', 'integration', 'formation', 'Market', 'Euratom', 'cooperation', 'development', 'energy', 'one', 'prestige', 'management', 'position', 'minds', 'people', 'things', 'holes', 'art', 'movies', 'girl', 'dreams', 'flower', 'elbows', 'body', 'potato', 'tune-belly', 'jury', 'Fulton', "ordinary's", 'court', 'fire', 'practices', 'appointment', 'appraisers', 'guardians', 'administrators', 'awarding', 'fees', 'compensation', 'precedent', 'time', 'capture', 'Helion', 'person', 'sketchbook', "Woolworth's", 'York', 'boat', 'frames', 'contact', 'plywood', 'planking', 'significance', 'volume', 'paragraphs', 'Laguerre', 'Hanover', 'Tar', 'Heel-Lotus', 'radioactivity', 'fallout', 'Cavalry', 'troopers', 'Palace', 'Emperor', 'tonight', 'Earl', 'examples', 'abuse', 'passages', 'Examiner', 'Destroyer', 'Character', 'Richard', 'Steele', 'Swift', 'truth', 'men', 'treatment', 'Robert', 'E.', 'Lee', 'dignity', 'confederacy', 'Heat', 'transfer', 'conduction', 'radiation', 'arc', 'column', 'maps', 'program', 'step', 'division', 'long-range', 'state', 'plan', 'series', 'inch', 'sheets', 'feet', 'Hong', 'Kong', 'India', 'Pakistan', 'exports', 'types', 'textiles', 'Britain', 'years', 'Lancashire', 'Pact', 'day', 'dogs', 'Ireland', 'pigs', 'fans', 'room', 'remnants', 'smoke', 'strata', 'ceiling', 'ship', 'Discovery', 'crew', 'nuclei', 'fibers', 'Figures', 'proliferation', 'structure', 'center', 'periphery', 'fiber', 'presence', 'artery', 'anastomoses', 'Ruysch', 'others', 'information', 'sampling', 'assesment', 'techniques', 'advisers', 'attention', 'uninitiate', 'confusion', 'operator', 'anybody', 'campaign', 'Mitchell', 'image', 'unity', 'candidate', 'Washington', 'kind', 'materialism', 'Artists', 'truck', 'transportation', 'dollars', 'luxuries', 'agency', 'Fiat', '$1.26', '$.03', 'kilometer', 'Station', 'Wagon', '$1.10', '$.105', 'Premier', 'Khrushchev', 'inauguration', 'meeting', 'President', 'Kennedy', 'problem', 'field', 'work', 'procedures', 'Felix', 'Kopstein', 'snake', 'maturity', 'python', 'exception', 'corner', 'lights', 'motor', 'children', 'section', 'countries', 'farms', 'Du', 'Pont', 'General', 'Motors', 'shares', 'stockholders', 'right', 'eyes', 'bridge', 'type', 'U.S.', 'highway', 'system', 'relic', 'horse', 'buggy', 'days', 'promise', 'lion', 'lamb', 'tense', 'spices', 'flavorings', 'condiments', 'values', 'talents', 'tile', 'dome', 'rug', 'poem', 'miniature', 'institutions', 'city', 'buildings', 'walls', 'lanes', 'plays', 'facets', 'experience', 'religion', 'today', 'tomorrow', 'quality', 'collection', 'monotony', 'pieces', "gourmet's", 'kitchen', 'breakfast', 'luncheon', 'party', 'rooms', 'everybody', 'mud', 'crank', 'calls', 'McFeeley', 'ch ...

# %%
basic_model = HiddenMarkovModel(name="base-hmm-tagger")

# TODO: create states with emission probability distributions P(word | tag) and add to the model
# (Hint: you may need to loop & create/add new states)
tag_states = {}
for tag in emission_counts:
    emission_prob = {word:emission_counts[tag][word]*1.0/tag_unigrams[tag] for word in emission_counts[tag].keys()}
    tag_emission = DiscreteDistribution(emission_prob)
    tag_states[tag] = State(tag_emission, name=tag)
    basic_model.add_states(tag_states[tag])
# TODO: add edges between states for the observed transition frequencies P(tag_i | tag_i-1)
# (Hint: you may need to loop & add transitions
# Transition probability for starting state
for tag in tag_starts:
    C_start = sum(tag_starts.values())
    transition_prob = {tag:tag_starts[tag]/C_start}
    basic_model.add_transition(basic_model.start, basic_model.states, transition_prob[tag])
# Transition probability for ending state
for tag in tag_ends:
    C_end = sum(tag_ends.values())
    transition_prob = {tag:tag_ends[tag]/C_start}
### take extra care here
    basic_model.add_transition(basic_model.states, basic_model.end, transition_prob[tag])
# Transition probability for all other states.
for tag1, tag2 in tag_bigrams.keys():
    transition_prob = {tag2:tag_bigrams[(tag1, tag2)]/tag_unigrams[tag1]}
    basic_model.add_transition(tag_states[tag1], tag_states[tag2], transition_prob[tag2])
# NOTE: YOU SHOULD NOT NEED TO MODIFY ANYTHING BELOW THIS LINE
# finalize the model
basic_model.bake()

assert all(tag in set(s.name for s in basic_model.states) for tag in data.training_set.tagset), \
       "Every state in your network should use the name of the associated tag, which must be one of the training set tags."
assert basic_model.edge_count() == 168, \
       ("Your network should have an edge from the start node to each state, one edge between every " +
        "pair of tags (states), and an edge from each state to the end node.")
HTML('<div class="alert alert-block alert-success">Your HMM network topology looks good!</div>')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-de3962908298> in <module>()
#      28 # NOTE: YOU SHOULD NOT NEED TO MODIFY ANYTHING BELOW THIS LINE
#      29 # finalize the model
# ---> 30 basic_model.bake()
#      31
#      32 assert all(tag in set(s.name for s in basic_model.states) for tag in data.training_set.tagset),        "Every state in your network should use the name of the associated tag, which must be one of the training set tags."
#
# pomegranate/hmm.pyx in pomegranate.hmm.HiddenMarkovModel.bake()
#
# AttributeError: 'NoneType' object has no attribute 'is_silent'

# %%
print(basic_model.states)
# Out:
# None

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, basic_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, basic_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))

assert hmm_training_acc > 0.97, "Uh oh. Your HMM accuracy on the training set doesn't look right."
assert hmm_testing_acc > 0.955, "Uh oh. Your HMM accuracy on the testing set doesn't look right."
HTML('<div class="alert alert-block alert-success">Your HMM tagger accuracy looks correct! Congratulations, you\'ve finished the project.</div>')

# %% [markdown]
# ### Example Decoding Sequences with the HMM Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, basic_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")

# %% [markdown]
# ## Finishing the project
# ---
#
# <div class="alert alert-block alert-info">
# **Note:** **SAVE YOUR NOTEBOOK**, then run the next cell to generate an HTML copy. You will zip & submit both this file and the HTML copy for review.
# </div>

# %%
# !!jupyter nbconvert *.ipynb

# %% [markdown]
# ## Step 4: [Optional] Improving model performance
# ---
# There are additional enhancements that can be incorporated into your tagger that improve performance on larger tagsets where the data sparsity problem is more significant. The data sparsity problem arises because the same amount of data split over more tags means there will be fewer samples in each tag, and there will be more missing data  tags that have zero occurrences in the data. The techniques in this section are optional.
#
# - [Laplace Smoothing](https://en.wikipedia.org/wiki/Additive_smoothing) (pseudocounts)
#     Laplace smoothing is a technique where you add a small, non-zero value to all observed counts to offset for unobserved values.
#
# - Backoff Smoothing
#     Another smoothing technique is to interpolate between n-grams for missing data. This method is more effective than Laplace smoothing at combatting the data sparsity problem. Refer to chapters 4, 9, and 10 of the [Speech & Language Processing](https://web.stanford.edu/~jurafsky/slp3/) book for more information.
#
# - Extending to Trigrams
#     HMM taggers have achieved better than 96% accuracy on this dataset with the full Penn treebank tagset using an architecture described in [this](http://www.coli.uni-saarland.de/~thorsten/publications/Brants-ANLP00.pdf) paper. Altering your HMM to achieve the same performance would require implementing deleted interpolation (described in the paper), incorporating trigram probabilities in your frequency tables, and re-implementing the Viterbi algorithm to consider three consecutive states instead of two.
#
# ### Obtain the Brown Corpus with a Larger Tagset
# Run the code below to download a copy of the brown corpus with the full NLTK tagset. You will need to research the available tagset information in the NLTK docs and determine the best way to extract the subset of NLTK tags you want to explore. If you write the following the format specified in Step 1, then you can reload the data using all of the code above for comparison.
#
# Refer to [Chapter 5](http://www.nltk.org/book/ch05.html) of the NLTK book for more information on the available tagsets.

# %%
import nltk
from nltk import pos_tag, word_tokenize
from nltk.corpus import brown

nltk.download('brown')
training_corpus = nltk.corpus.brown
training_corpus.tagged_sents()[0]
